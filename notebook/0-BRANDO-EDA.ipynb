# %%
import pandas as pd
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vitor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vitor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vitor\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import os

directory = '../data/tratados/'
file_list = os.listdir(directory)
for i in file_list:
    print('df_' + i)
# Out:
# df_t_cond_add.csv
# df_t_cond_familia.csv
# df_t_cons_reg.csv
# df_t_diag_status.csv
# df_t_gravidez.csv
# df_t_lab_aac.csv
# df_t_lab_basic.csv
# df_t_lab_hemat.csv
# df_t_lab_quimica.csv
# df_t_lab_sorol.csv
# df_t_liquor.csv
# df_t_mri.csv
# df_t_pacientes_reg.csv
# df_t_pot_evoc.csv
# df_t_surtos_reg.csv
# df_t_trat_dmd.csv
# df_t_trat_odr.csv
# df_t_trat_out.csv
# df_t_vacinas_reg.csv

# %%
df_cond_add = pd.read_csv(r'..\data\tratados\t_cond_add.csv', sep=';', encoding='utf-8') # Coluna coment_cond_add
df_cond_add.dropna(inplace=True)
df_cond_familia = pd.read_csv(r'..\data\tratados\t_cond_familia.csv', sep=';', encoding='utf-8') # Coluna coment_cond_familia
df_cond_familia.dropna(inplace=True)
df_cons_reg = pd.read_csv(r'..\data\tratados\t_cons_reg.csv', sep=';', encoding='utf-8') # Coluna coment_cons_reg
df_cons_reg.dropna(inplace=True)
df_diag_status = pd.read_csv(r'..\data\tratados\t_diag_status.csv', sep=';', encoding='utf-8') # Coluna coment_diag_status
df_diag_status.dropna(inplace=True)
df_gravidez = pd.read_csv(r'..\data\tratados\t_gravidez.csv', sep=';', encoding='utf-8') # Coluna coment_gravidez
df_gravidez.dropna(inplace=True)
df_lab_aac = pd.read_csv(r'..\data\tratados\t_lab_aac.csv', sep=';', encoding='utf-8') # Coluna coment_lab_aac
df_lab_aac.dropna(inplace=True)
df_lab_basic = pd.read_csv(r'..\data\tratados\t_lab_basic.csv', sep=';', encoding='utf-8') # Coluna coment_lab_basic
df_lab_basic.dropna(inplace=True)
df_lab_hemat = pd.read_csv(r'..\data\tratados\t_lab_hemat.csv', sep=';', encoding='utf-8') # Coluna coment_lab_hemat
df_lab_hemat.dropna(inplace=True)
df_lab_quimica = pd.read_csv(r'..\data\tratados\t_lab_quimica.csv', sep=';', encoding='utf-8') # Coluna coment_lab_quimica
df_lab_quimica.dropna(inplace=True)
df_lab_sorol = pd.read_csv(r'..\data\tratados\t_lab_sorol.csv', sep=';', encoding='utf-8') # Coluna coment_lab_sorol
df_lab_sorol.dropna(inplace=True)
df_liquor = pd.read_csv(r'..\data\tratados\t_liquor.csv', sep=';', encoding='utf-8') # Coluna coment_liquor
df_liquor.dropna(inplace=True)
df_mri = pd.read_csv(r'..\data\tratados\t_mri.csv', sep=';', encoding='utf-8') # Coluna coment_mri
df_mri.dropna(inplace=True)
df_pacientes_reg = pd.read_csv(r'..\data\tratados\t_pacientes_reg.csv', sep=';', encoding='utf-8') # Coluna coment_pacientes_reg, mais informações para métricas
df_pot_evoc = pd.read_csv(r'..\data\tratados\t_pot_evoc.csv', sep=';', encoding='utf-8') # Coluna coment_pot_evoc
df_pot_evoc.dropna(inplace=True)
df_surtos_reg = pd.read_csv(r'..\data\tratados\t_surtos_reg.csv', sep=';', encoding='utf-8') # Coluna coment_surtos_reg
df_surtos_reg.dropna(inplace=True)
df_trat_dmd = pd.read_csv(r'..\data\tratados\t_trat_dmd.csv', sep=';', encoding='utf-8') # Coluna coment_trat_dmd
df_trat_dmd.dropna(inplace=True)
df_trat_odr = pd.read_csv(r'..\data\tratados\t_trat_odr.csv', sep=';', encoding='utf-8') # Coluna coment_trat_odr
df_trat_odr.dropna(inplace=True)
df_trat_out = pd.read_csv(r'..\data\tratados\t_trat_out.csv', sep=';', encoding='utf-8') # Coluna coment_trat_out
df_trat_out.dropna(inplace=True)
df_vacinas_reg = pd.read_csv(r'..\data\tratados\t_vacinas_reg.csv', sep=';', encoding='utf-8') # Coluna coment_vacinas_reg
df_vacinas_reg.dropna(inplace=True)

# %%
dict_brando = {
    "NO": "neurite óptica",
    "MT": "mielite transversa",
    "MTLE": "mielite transversa longitudinalmente extensa",
    "LETM": "mielite transversa longitudinalmente extensa",
    "NMO": "doença do espectro da neuromielite óptica",
    "NMOSD": "doença do espectro da neuromielite óptica",
    "DENMO": "doença do espectro da neuromielite óptica",
    "MOGAD": "doença associada ao anticorpo anti-MOG",
    "MONEM": "doença associada ao anticorpo anti-MOG",
    "LEMP": "leucoencefalopatia multifocal progressiva",
    "PML": "leucoencefalopatia multifocal progressiva",
    "DM": "diabete mellitus",
    "HAS": "hipertensão arterial sistêmica",
    "AVE": "derrame cerebral",
    "AVC": "derrame cerebral",
    "THB": "bipolaridade",
    "TAB": "bipolaridade",
    "transtorno do humor bipolar": "bipolaridade",
    "transtorno afetivo bipolar": "bipolaridade",
    "IAM": "infarto agudo do miocárdio",
    "IC": "insuficiência cardíaca",
    "ICE": "insuficiência cardíaca",
    "ICC": "insuficiência cardíaca",
    "Ca": "neoplasia",
    "Tu": "neoplasia",
    "TB": "tuberculose",
    "TBC": "tuberculose",
    "PPD": "PPD (teste para tuberculose)",
    "Mantoux": "Mantoux (teste para tuberculose)",
    "AIDS": "HIV +",
    "SIDA": "HIV +",
    "VDRL+": "sífilis",
    "reag.": "sífilis",
    "reagente": "sífilis",
    "HBV": "hepatite B",
    "HBsAg +": "hepatite B",
    "HCV +": "hepatite C",
    "HAV+": "hepatite A",
    "HSV": "vírus do herpes simples",
    "VZV": "vírus varicela-zoster",
    "CMV": "citomegalovírus",
    "Toxo": "toxoplasmose",
    "EBV": "vírus Epstein-Barr",
    "HTLV": "vírus linfotrópico de células T humanas",
    "MMR": "sarampo, caxumba e rubéola",
    "HPV": "papilomavírus humano",
    "VSR": "Vírus Sincicial Respiratório",
    "RSV": "Vírus Sincicial Respiratório",
    "DPOC": "doença pulmonar obstrutiva crônica",
    "DBPOC": "doença pulmonar obstrutiva crônica",
    "COPD": "doença pulmonar obstrutiva crônica",
    "STC": "síndrome do túnel do carpo",
    "PNP": "polineuropatia",
    "ELA": "esclerose lateral amiotrófica",
    "MG": "miastenia gravis",
    "RGE": "refluxo gastroesofágico",
    "DRGE": "refluxo gastroesofágico",
    "IVAS": "infecção de vias aéreas superiores",
    "BCP": "broncopneumonia",
    "PTI": "púrpura trombocitopênica idiopática",
    "TVP": "trombose venosa profunda",
    "TEP": "tromboembolismo pulmonar",
    "OMA": "otite média aguda",
    "TAG": "transtorno de ansiedade generalizada",
    "ITU": "infecção do trato urinário",
    "ACFA": "arritmia cardíaca fibrilação atrial",
    "AIDP": "polineuropatia inflamatória desmielinizante aguda",
    "GBS": "polineuropatia inflamatória desmielinizante aguda",
    "SGB": "polineuropatia inflamatória desmielinizante aguda",
    "CIDP": "polineuropatia inflamatória desmielinizante crônica",
    "QP": "queixa principal",
    "HDA": "história da doença atual",
    "RS": "revisão de sistemas",
    "HMP": "história médica pregressa",
    "HF": "história familiar",
    "PPS": "perfil psicossocial",
    "NC": "nervos (pares) cranianos",
    "PC": "nervos (pares) cranianos",
    "MOE": "motricidade ocular extrínseca (nervos cranianos III, IV e VI)",
    "PIFR": "pupilas isofotorreagentes (normal)",
    "AV": "acuidade visual",
    "Snellen": "acuidade visual medido pela escala de Snellen",
    "OE": "olho esquerdo",
    "OD": "olho direito",
    "AO": "ambos os olhos",
    "FO": "fundo de olho",
    "fundoscopia": "fundo de olho",
    "DPAR": "déficit pupilar aferente",
    "OIN": "oftalmoplegia internuclear",
    "RCP": "reflexo cutâneo plantar",
    "reflexo cutâneo plantar extensor": "Babinski +",
    "reflexo cutâneo plantar flexor": "Babinski -",
    "MSD": "membro superior direito",
    "MSE": "membro superior esquerdo",
    "MID": "membro inferior direito",
    "MIE": "membro inferior esquerdo",
    "MMSS": "membros superiores",
    "MMII": "membros inferiores",
    "MsSs": "membros superiores",
    "MsIs": "membros inferiores",
    "Hemicorpo": "um lado do corpo",
    "FM": "força muscular (graus 0 a 5)",
    "Hemiparesia": "diminuição de força em um lado do corpo (força entre 1 e 4)",
    "Paraparesia": "diminuição de força nos membros inferiores (força entre 1 e 4)",
    "Tetraparesia": "diminuição de força nos quatro membros (força entre 1 e 4)",
    "Hemiplegia": "ausência de força em um lado do corpo (força grau 0)",
    "Paraplegia": "ausência de força nos membros inferiores (força grau 0)",
    "Tetraplegia": "ausência de força nos quatro membros (força grau 0)",
    "ROT": "reflexos tendinosos",
    "Hiperreflexia": "reflexo grau 4",
    "Hiporreflexia": "reflexo grau 1",
    "Arreflexia": "reflexo grau 0",
    "SV": "sinais vitais",
    "SVs": "sinais vitais",
    "BEG": "bom estado geral",
    "LOC": "lúcido, orientado, coerente",
    "MUC": "mucosas úmidas e coradas",
    "PA": "pressão arterial",
    "PAS": "pressão arterial sistólica",
    "PAd": "pressão arterial diastólica",
    "MV": "murmúrio vesicular",
    "BCRNF": "bulhas cardíacas rítmicas normofônicas",
    "sp": "sem particularidades (normal)",
    "dx": "diagnóstico",
    "hx": "história",
    "IH": "intra-hospitalar",
    "Tto": "tratamento",
    "JC": "vírus JC",
    "vírus JC": "vírus JC",
    "JCV": "vírus JC",
    "VJC": "vírus JC",
    "Ac": "anticorpo",
    "Fisio M": "fisioterapia motora",
    "Fisio R": "fisioterapia respiratória",
    "Fisio M +R": "fisioterapia motora e respiratória",
    "JUP": "junção ureteropélvica",
    "NEDA": "sem evidência de doença ativa",
    "SNC": "sistema nervoso central",
    "SNP": "sistema nervoso periférico",
    "SNA": "sistema nervoso autônomo",
    "EM": "esclerose múltipla",
    "AQP4": "aquaporina-4",
    "MOG": "Glicoproteína Mielina Oligodendrócito",
    "ADEM": "encefalomielite disseminada aguda",
    "BCTRIMS": "Comitê Brasileiro de Tratamento e Pesquisa em Esclerose Múltipla",
    "ECTRIMS": "Comitê Europeu de Tratamento e Pesquisa em Esclerose Múltipla",
    "LACTRIMS": "Comitê Latino-americano de Tratamento e Pesquisa em Esclerose Múltipla",
    "ACTRIMS": "Comitê Norte-americano de Tratamento e Pesquisa em Esclerose Múltipla",
    "PACTRIMS": "Comitê Pan-asiático de Tratamento e Pesquisa em Esclerose Múltipla",
    "AAN": "Academia Americana de Neurologia",
    "ABN": "Academia Brasileira de Neurologia",
    "ANVISA": "Agência Nacional de Vigilância Sanitária",
    "SUS": "Sistema Único de Saúde",
    "MS": "Ministério da Saúde",
    "SES": "Secretaria Estadual de Saúde",
    "CREMERS": "Conselho Regional de Medicina do Rio Grande do Sul",
    "CRM": "Conselho Regional de Medicina",
    "FENhance": "estudo clínico com medicação experimental",
    "GEMINI": "estudo clínico com medicação experimental",
    "REMIT": "estudo clínico com medicação experimental",
    "ORATORIO": "estudo clínico com medicação experimental",
    "CONSONANSCE": "estudo clínico com medicação experimental",
    "DBR03T": "estudo clínico com medicação experimental",
    "EDSS": "Escala Expandida de Estado de Incapacidade",
    "SF do EDSS": "sistema funcional da Escala Expandida de Estado de Incapacidade",
    "MSFC": "multiple sclerosis functional composite",
    "PASAT": "escala para avaliar a cognição",
    "9HPT": "teste dos 9 pinos",
    "T25FW": "Teste de caminhada (de 25 pés ou 7,62m)",
    "T25-FW": "Teste de caminhada (de 25 pés ou 7,62m)",
    "SDMT": "Symbol Digit Modalities Test",
    "DMD": "droga modificadora da doença",
    "DMT": "terapia modificadora da doença",
    "DMF": "fumarato de dimetila (Tecfidera)",
    "fumarato": "fumarato de dimetila (Tecfidera)",
    "dimetil-fumarato": "fumarato de dimetila (Tecfidera)",
    "NTZ": "natalizumabe (Tysabri)",
    "nata": "natalizumabe (Tysabri)",
    "OCR": "ocrelizumabe (Ocrevus)",
    "acre": "ocrelizumabe (Ocrevus)",
    "Fingo": "fingolimode (Gilenya)",
    "FTY": "fingolimode (Gilenya)",
    "FTY720": "fingolimode (Gilenya)",
    "Clad.": "cladribina (Mavenclad)",
    "AG": "acetato de glatirâmer (Copaxone)",
    "GA": "acetato de glatirâmer (Copaxone)",
    "IFN": "betainterferona",
    "interferon": "betainterferona",
    "beta-IFN": "betainterferona",
    "IFN-beta": "betainterferona",
    "Teri": "teriflunomida (Aubagio)",
    "ALE": "alentuzumabe (Lemtrada)",
    "ALTZ": "alentuzumabe (Lemtrada)",
    "alentu": "alentuzumabe (Lemtrada)",
    "OFA": "ofatumumabe (Kesimpta)",
    "ofa": "ofatumumabe (Kesimpta)",
    "SIPO": "siponimode (Kiendra)",
    "sipo": "siponimode (Kiendra)",
    "MP": "metilprednisolona",
    "solumedrol": "metilprednisolona",
    "MPIV": "metilprednisolona intravenosa",
    "MPVO": "metilprednisolona via oral",
    "Fampyra": "pampridina",
    "HCTZ": "hidroclorotiazida",
    "ACO": "anticoncepcional oral",
    "AINE": "anti-inflamatório não esteroide",
    "ATB": "antibiótico",
    "THC": "canabidiol",
    "CBD": "canabidiol",
    "Mevatyl": "canabidiol",
    "BTX": "toxina botulínica",
    "BTX-A": "toxina botulínica",
    "TB": "toxina botulínica",
    "BOTOX": "toxina botulínica",
    "Dysport": "toxina botulínica",
    "DAE": "droga antiepiléptica",
    "DFH": "fenitoína",
    "CBZ": "carbamazepina",
    "OCZ": "oxcarbazepina",
    "GBP": "gabapentina",
    "VPA": "ácido valproico",
    "RTX": "rituximabe",
    "AZA": "azatioprina",
    "MMF": "micofenolato de mofetila",
    "MTX": "metotrexato",
    "CF": "ciclofosfamida",
    "CYC": "ciclofosfamida",
    "IVIG": "imunoglobulina humana intravenosa",
    "AHSCT": "Transplante Autólogo de Células-Tronco Hematopoéticas",
    "TMO": "Transplante de Medula Óssea",
    "BMT": "Transplante de Medula Óssea",
    "RIS": "síndrome radiologicamente isolada",
    "SRI": "síndrome radiologicamente isolada",
    "CIS": "síndrome clínica isolada",
    "SCI": "síndrome clínica isolada",
    "EMRR": "esclerose múltipla remitente-recorrente (ou surto-supressão)",
    "EMSS": "esclerose múltipla remitente-recorrente (ou surto-supressão)",
    "EMSP": "esclerose múltipla secundariamente progressiva",
    "EMPP": "esclerose múltipla primariamente progressiva"
}

# Colocar key e value dos dicionarios em lower case
dict_brando = dict((k.lower(), v.lower()) for k, v in dict_brando.items())

# %%
def replace_func(match):
        # Recuperar o acrônimo correspondente em minúsculas
        acr = match.group().lower()
        # Retornar a definição completa do acrônimo
        return dict_brando.get(acr, acr)  # Retorna o acrônimo se não encontrado no dicionário


def remove_x000d(text):
    return text.replace('_x000d_', '')


def expand_acronyms(text):
# Compilar o padrão de regex com todos os acrônimos
    text = remove_x000d(text)
    pattern = re.compile(r'\b(' + '|'.join(dict_brando.keys()) + r')\b', re.IGNORECASE)

    # Substituir acrônimos no texto
    return pattern.sub(replace_func, text)


def transform_text(text):
    # Clean text
    text = text.replace(r'[^a-zA-Z0-9\s]', '',)
    text = text.lower()
    return text


def tokenize(text):
    # Tokenize text
    tokens = nltk.tokenize.word_tokenize(text)
    return tokens   


def remove_stopwords(tokens):
    # Remove stopwords from tokens
    stopwords = set(nltk.corpus.stopwords.words('portuguese'))
    filtered_tokens = [token for token in tokens if token not in stopwords]
    return filtered_tokens

def lemmatize(tokens):
    # Lemmatize tokens
    lemmatizer = nltk.stem.WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens


def preprocess_text(text):
    text = transform_text(text)
    text = expand_acronyms(text)
    tokens = tokenize(text)
    tokens = remove_stopwords(tokens)
    tokens = lemmatize(tokens)
    return tokens

# %%
#apply to all dataframes
df_cond_add['coment_cond_add_tokenized'] = df_cond_add['coment_cond_add'].apply(preprocess_text)
df_cond_familia['coment_cond_familia_tokenized'] = df_cond_familia['coment_cond_familia'].apply(preprocess_text)
df_cons_reg['coment_cons_reg_tokenized'] = df_cons_reg['coment_cons_reg'].apply(preprocess_text)
df_diag_status['coment_diag_status_tokenized'] = df_diag_status['coment_diag_status'].apply(preprocess_text)
df_gravidez['coment_gravidez_tokenized'] = df_gravidez['coment_gravidez'].apply(preprocess_text)
df_lab_aac['coment_lab_aac_tokenized'] = df_lab_aac['coment_lab_aac'].apply(preprocess_text)
df_lab_basic['coment_lab_basic_tokenized'] = df_lab_basic['coment_lab_basic'].apply(preprocess_text)
df_lab_hemat['coment_lab_hemat_tokenized'] = df_lab_hemat['coment_lab_hemat'].apply(preprocess_text)
df_lab_quimica['coment_lab_quimica_tokenized'] = df_lab_quimica['coment_lab_quimica'].apply(preprocess_text)
df_lab_sorol['coment_lab_sorol_tokenized'] = df_lab_sorol['coment_lab_sorol'].apply(preprocess_text)
df_liquor['coment_liquor_tokenized'] = df_liquor['coment_liquor'].apply(preprocess_text)
df_mri['coment_mri_tokenized'] = df_mri['coment_mri'].apply(preprocess_text)
df_pot_evoc['coment_pot_evoc_tokenized'] = df_pot_evoc['coment_pot_evoc'].apply(preprocess_text)
df_surtos_reg['coment_surtos_reg_tokenized'] = df_surtos_reg['coment_surtos_reg'].apply(preprocess_text)
df_trat_dmd['coment_trat_dmd_tokenized'] = df_trat_dmd['coment_trat_dmd'].apply(preprocess_text)
df_trat_odr['coment_trat_odr_tokenized'] = df_trat_odr['coment_trat_odr'].apply(preprocess_text)
df_trat_out['coment_trat_out_tokenized'] = df_trat_out['coment_trat_out'].apply(preprocess_text)
df_vacinas_reg['coment_vacinas_reg_tokenized'] = df_vacinas_reg['coment_vacinas_reg'].apply(preprocess_text)
